# %% [markdown]
# <a href="https://colab.research.google.com/github/BiancaClementino/DataScrappingCW/blob/master/Request.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Mining of the data out of the HTML**

# %% [markdown]
# ## **Wimbledon 2019 Data Mining**

# %%
from bs4 import BeautifulSoup

# %%
wimb_html="""
<html>
			<div class="page" role="main"><section class="wrapper scorespage"><div class="scores-background"></div><div class="header-global"><div class="logotitle"><div class="logotitle-image"><a href="/index.html"><div title="The Championships, Wimbledon" class="wim-logo"></div></a></div><div class="logotitle-titles"><div class="title-txt title-txt-page show" display-bg="dark"><div class="title-txt-page__name"><h1><div class="jsx-parser">Draws</div></h1></div></div></div></div><div class="logosearch"><div class="login"><div class="name"><span class="text">LOGIN</span><span class="vertical_divide"></span></div></div><a href="/en_GB/search/index.html"><i class="icon-search"></i></a><a href="https://www.ibm.com/Wimbledon" class=" external" target="_blank"><span class="logo-small"><img class="ibm-logo" alt="IBM Logo" src="/assets/images/logos/ibm-logo-small.png"></span><span class="logo-standard"><img class="ibm-logo" alt="IBM Logo" src="/assets/images/logos/ibm-logo.png"></span></a></div><div class="live-status small"><div class="title">LIVE</div><a class="" href="/en_GB/scores/results/index.html"><div class="symbol scores"><i class="icon-scores"></i><div class="label">SCORES</div></div></a><div class="line"></div><a class="" href="/en_GB/video/index.html"><div class="symbol video"><i class="icon-video"></i><div class="label">VIDEO</div></div></a><div class="line"></div><div class="symbol radio"><i class="icon-radio"></i><div class="label">RADIO</div></div></div></div><nav class="mainnav" display-state="hidden"><button class="open" type="button" data-target="#navbar-main" aria-controls="navbar-main" aria-expanded="false" aria-label="Open Menu"><i class="icon-hamburger"></i></button><div class="mainnav--wrapper" display-state="hidden"><div class="mainnav--header"><button class="close" type="button" data-target="#navbar-main" aria-controls="navbar-main" aria-expanded="true" aria-label="Close Menu"><i class="icon-close"></i></button><div class="logotitle"><div class="logotitle-image" display-bg="dark"><a class="" href="/index.html"><div title="The Championships, Wimbledon" class="wim-logo"></div></a></div><div class="logotitle-txt" display-bg="dark"><div class="logotitle-txt__dates">1 July - 14 July 2019</div></div><div class="logotitle-line" display-bg="dark"></div></div></div><div class="mainnav--content-main"><div class="mainnav--content-main-nav" id="navbar-main"><ul class="navbar"><li class="nav-item"><a><span class="myWimbledon"><i class="icon-myw my"></i><span class="wimbledon">Wimbledon</span></span></a><div class="bottom-highlight"></div><ul class="nav-item-subnav"><div class="submenu"><div class="myWimSubnav"><span>Login</span> / <span>Register</span><div class="line"></div><div><a class="" href="/en_GB/aboutmywimbledon/index.html">About <span class="myWimbledon"><i class="icon-myw my"></i><span class="wimbledon">Wimbledon</span></span></a></div></div></div><div class="feature-label">Featured</div><li class="feature-pic"><a class="" href="/en_GB/foundation/index.html"><div class="feature-image"><img alt="Foundation" src="/images/pics/thumbs/w_foundationactive1.jpg"></div>Foundation</a></li><li class="feature-pic"><a class="" href="/en_GB/museum_and_tours/index.html"><div class="feature-image"><img alt="Museum" src="/images/pics/thumbs/w_museumheader2.jpg"></div>Museum</a></li></ul></li><li class="nav-item"><a class="" href="/index.html">Home</a><div class="bottom-highlight"></div></li><li class="nav-item"><a>News</a><div class="bottom-highlight"></div><ul class="nav-item-subnav"><div class="submenu"><li><a class="" href="/en_GB/news/index.html">News</a></li><li><a class="" href="/en_GB/news/index.html?filter=interview">Interviews</a></li><li><a class="" href="/en_GB/news/index.html?filter=gallery">Photos</a></li><li><a class="" href="/en_GB/news/mobile.html">Mobile Apps</a></li><li><a class="" href="/en_GB/weather/index.html">Weather</a></li></div><div class="feature-label">Featured</div><li class="feature-pic"><a class="" href="/en_GB/news/index.html"><div class="feature-image"><img alt="News" src="/images/pics/thumbs/w_13_djokovic308_aeltc_jbuckle.jpg"></div>News</a></li><li class="feature-pic"><a class="" href="/en_GB/news/index.html?filter=gallery"><div class="feature-image"><img alt="Photos" src="/images/pics/thumbs/w_020715_225_brown_aeltc_ek.jpg"></div>Photos</a></li></ul></li><li class="nav-item"><a>Scores &amp; Schedule</a><div class="bottom-highlight"></div><ul class="nav-item-subnav"><div class="submenu"><li><a class="" href="/en_GB/scores/schedule/index.html">Order of Play</a></li><li><a class="" href="/en_GB/scores/index.html">Live Scores</a></li><li><a class="" href="/en_GB/scores/results/index.html">Results</a></li><li><a class="" href="/en_GB/atoz/schedule.html">Event Schedule</a></li><li><a class="" href="/en_GB/atoz/tv_schedules.html">TV Schedule</a></li></div><div class="feature-label">Featured</div><li class="feature-pic"><a class="" href="/en_GB/video/highlights.html"><div class="feature-image"><img alt="Video Highlights" src="/images/pics/thumbs/w_hingis_murray_kontinen_watson_938_160717_jm.jpg"></div>Video Highlights</a></li><li class="feature-pic"><a class="" href="/en_GB/scores/extrastats/index.html"><div class="feature-image"><img alt="Statistics" src="/images/pics/thumbs/w_05_GV_116_AELTC_JB.jpg"></div>Statistics</a></li></ul></li><li class="nav-item nav-item-open"><a>Draws</a><div class="bottom-highlight"></div><ul class="nav-item-subnav nav-item-subnav-open"><div class="submenu"><li><a class="" href="/en_GB/draws/index.html?event=MS">Gentlemen's Singles</a></li><li><a class="" href="/en_GB/draws/index.html?event=LS">Ladies' Singles</a></li><li><a class="" href="/en_GB/draws/index.html?event=MD">Gentlemen's Doubles</a></li><li><a class="" href="/en_GB/draws/index.html?event=LD">Ladies' Doubles</a></li><li><a class="" href="/en_GB/draws/index.html?event=MX">Mixed Doubles</a></li><li><a class="" href="/en_GB/draws/index.html?event=BS">Juniors</a></li><li><a class="" href="/en_GB/draws/od/index.html">Invitation Doubles</a></li><li><a class="" href="/en_GB/draws/index.html?event=DM">Wheelchairs</a></li><li><a class="" href="/en_GB/draws/index.html?event=QS">Qualifying</a></li><li><a class="" href="/en_GB/draws_archive/index.html">Archive</a></li></div><div class="feature-label">Featured</div><li class="feature-pic"><a class="" href="/en_GB/draws_archive/index.html"><div class="feature-image"><img alt="Archive Draws" src="/images/pics/thumbs/w_q06_ambient_30_aeltc_m_hangst.jpg"></div>Archive Draws</a></li><li class="feature-pic"><a class="" href="/en_GB/atoz/entry_lists.html"><div class="feature-image"><img alt="Entry Lists 2019" src="/images/pics/thumbs/w_300615_25_ambient_aeltc_t_lovelock.jpg"></div>Entry Lists 2019</a></li></ul></li><li class="nav-item"><a>Players</a><div class="bottom-highlight"></div><ul class="nav-item-subnav"><div class="submenu"><li><a class="" href="/en_GB/players/index.html">Player Profiles</a></li><li><a class="" href="/en_GB/players/competitors/index.html">Competitor List</a></li><li><a class="" href="/en_GB/scores/extrastats/index.html">Player Statistics</a></li><li><a class="" href="/en_GB/scores/nations/scoreboard.html">Country Statistics</a></li><li><a class="" href="/en_GB/scores/challenge/index.html">Player Challenge</a></li><li><a class="" href="/en_GB/draws_archive/champions/champions.html">Rolls of Honour</a></li><li><a class="" href="/en_GB/draws_archive/index.html">Archive</a></li></div><div class="feature-label">Featured</div><li class="feature-pic"><a class="" href="/en_GB/atoz/entry_lists.html"><div class="feature-image"><img alt="Entry Lists" src="/images/pics/thumbs/w_preps_2019_180626_tl_copy.jpg"></div>Entry Lists</a></li><li class="feature-pic"><a class="" href="/en_GB/atoz/wild_cards.html"><div class="feature-image"><img alt="Wild Cards" src="/images/pics/thumbs/w_centre_1679_180715_jm.jpg"></div>Wild Cards</a></li></ul></li><li class="nav-item"><a>Video &amp; Radio</a><div class="bottom-highlight"></div><ul class="nav-item-subnav"><div class="submenu"><li><a class="" href="/en_GB/video/index.html">Latest</a></li><li><a class="" href="/en_GB/video/highlights.html">Highlights</a></li><li><a class="" href="/en_GB/video/features.html">Features</a></li><li><a class="" href="/en_GB/video/interviews.html">Interviews</a></li><li><a class="" href="/en_GB/video/pod.html">Podcasts</a></li><li><a class="" href="/en_GB/video/archive.html">Throwbacks</a></li><li><a class="" href="/en_GB/interactive/index.html">LIVE Video</a></li><li><a class="" href="/en_GB/interactive/radio.html">LIVE Radio</a></li></div><div class="feature-label">Featured</div><li class="feature-pic"><a class="" href="/en_GB/video/highlights.html"><div class="feature-image"><img alt="Highlights" src="/images/pics/thumbs/w_muguruza_859_150717_bs.jpg"></div>Highlights</a></li><li class="feature-pic"><a class="" href="/en_GB/video/interviews.html"><div class="feature-image"><img alt="Interviews" src="/images/pics/thumbs/w_fedmon5.jpg"></div>Interviews</a></li></ul></li><li class="nav-item"><a>Visit &amp; Tickets</a><div class="bottom-highlight"></div><ul class="nav-item-subnav"><div class="submenu"><li><a class="" href="/en_GB/museum_and_tours/index.html">Museum &amp; Tours</a></li><li><a class="" href="/en_GB/tickets/index.html">Tickets</a></li><li><a class="" href="/en_GB/debentures/index.html">Debentures</a></li><li><a class="" href="/en_GB/hospitality/index.html">Hospitality</a></li><li><a class="" href="/en_GB/foodanddrink/index.html">Food &amp; Drink</a></li><li><a class="" href="/en_GB/learning/index.html">Learning</a></li><li><a class="" href="/en_GB/your_visit/index.html">Your Visit</a></li><li><a class="" href="/en_GB/atoz/getting_here.html">Travel &amp; Parking</a></li><li><a class="" href="/en_GB/atoz/index.html">A-Z Guide</a></li></div><div class="feature-label">Featured</div><li class="feature-pic"><a class="" href="/en_GB/atoz/safety_and_security.html"><div class="feature-image"><img alt="Security" src="/images/pics/thumbs/m_aerial_812_180712_jt.jpg"></div>Security</a></li><li class="feature-pic"><a class="" href="/en_GB/search/index.html"><div class="feature-image"><img alt="A-Z Visitor Guide" src="/images/pics/thumbs/w_aerial_808_180712_jt.jpg"></div>A-Z Visitor Guide</a></li></ul></li><li class="nav-item"><a>Shop</a><div class="bottom-highlight"></div><ul class="nav-item-subnav"><div class="submenu"><li><a class="" href="/en_GB/atoz/shopping.html">Shop at Wimbledon</a></li><li><a href="http://shop.wimbledon.com/stores/wimbledon/default.aspx?portal=CRCDQRLH&amp;CMP=PSC-CRCDQRLH" class=" external" target="_blank">Shop Online</a></li><li><a href="http://shop.wimbledon.com/stores/wimbledon/products/product_browse.aspx?category|category_root|7618=Towels&amp;portal=M3BG8D21&amp;CMP=PSC-M3BG8D21" class=" external" target="_blank">Towels</a></li><li><a href="http://shop.wimbledon.com/stores/wimbledon/products/product_browse.aspx?category|category_root|7616=Fashion&amp;portal=HUT3NS59&amp;CMP=PSC-HUT3NS59" class=" external" target="_blank">Fashion</a></li><li><a href="http://shop.wimbledon.com/stores/wimbledon/products/product_browse.aspx?category|category_root|7617=Ralph%20Lauren&amp;portal=WI1UL1BC&amp;CMP=PSC-WI1UL1BC" class=" external" target="_blank">Ralph Lauren</a></li><li><a href="http://shop.wimbledon.com/stores/wimbledon/en/c/equipment?portal=LS6E9NF6&amp;CMP=PSC-LS6E9NF6" class=" external" target="_blank">Equipment</a></li><li><a href="http://shop.wimbledon.com/stores/wimbledon/products/product_browse.aspx?category|category_root|7621=Gifts&amp;portal=G68N52NM&amp;CMP=PSC-G68N52NM" class=" external" target="_blank">Gifts</a></li><li><a href="http://shop.wimbledon.com/stores/wimbledon/products/product_browse.aspx?category|category_root|42368=Brand&amp;portal=IW5HUPQ8&amp;CMP=PSC-IW5HUPQ8a" class=" external" target="_blank">Brands</a></li></div><div class="feature-label">Featured</div><li class="feature-pic"><a href="http://shop.wimbledon.com/stores/wimbledon/en/c/fashion?portal=ZKQOUUT5&amp;amp;CMP=PSC-ZKQOUUT5" class=" external" target="_blank"><div class="feature-image"><img alt="The Wimbledon Collection" src="/images/pics/misc/Navigation_banner_new-fashion.jpg"></div>The Wimbledon Collection</a></li><li class="feature-pic"><a href="http://shop.wimbledon.com/stores/wimbledon/en/c/towels?portal=M3BG8D21&amp;amp;CMP=PSC-M3BG8D21&amp;amp;culture=en" class=" external" target="_blank"><div class="feature-image"><img alt="Official 2019 Towels" src="/images/pics/misc/navigation_banner2019towel.jpg"></div>Official 2019 Towels</a></li></ul></li><li class="nav-item"><a>About</a><div class="bottom-highlight"></div><ul class="nav-item-subnav"><div class="submenu"><li><a class="" href="/en_GB/about_wimbledon/index.html">About Wimbledon</a></li><li><a class="" href="/en_GB/atoz/history.html">History</a></li><li><a class="" href="/en_GB/jobs/index.html">Jobs</a></li><li><a class="" href="/en_GB/atoz/official_suppliers.html">Official Suppliers</a></li><li><a class="" href="/en_GB/media/index.html">Media</a></li><li><a class="" href="/en_GB/atoz/tv_schedules.html">TV Coverage</a></li><li><a class="" href="/en_GB/contact/index.html">Contact</a></li></div><div class="feature-label">Featured</div><li class="feature-pic"><a class="" href="/en_GB/about_wimbledon/index.html"><div class="feature-image"><img alt="About Wimbledon" src="/images/pics/thumbs/w_atmosphere2_2206_jb.jpg"></div>About Wimbledon</a></li><li class="feature-pic"><a class="" href="/en_GB/aboutwimbledon/master_plan.html"><div class="feature-image"><img alt="Master Plan" src="/images/pics/thumbs/w_Masterplan-830.jpg"></div>Master Plan</a></li></ul></li><li class="nav-item"><a>Foundation</a><div class="bottom-highlight"></div><ul class="nav-item-subnav"><div class="submenu"><li><a class="" href="/en_GB/foundation/index.html">About</a></li><li><a href="/pdf/AnnualReview2018.pdf" class=" download" target="_blank">Annual Review</a></li><li><a class="" href="/en_GB/wimbledonfoundation/apply.html">Apply</a></li><li><a class="" href="/en_GB/wimbledonfoundation/timeline.html">Timeline</a></li></div><div class="feature-label">Featured</div><li class="feature-pic"><a class="" href="/en_GB/about_wimbledon/no1_court_celebration.html"><div class="feature-image"><img alt="The No.1 Court Celebration" src="/images/pics/thumbs/w_No1Header.png"></div>The No.1 Court Celebration</a></li><li class="feature-pic"><a class="" href="/en_GB/news/articles/2019-04-20/a_roof_for_all_a_wimbledon_foundation_auction.html"><div class="feature-image"><img alt="A Roof for All" src="/images/pics/thumbs/w_grounds_aerial_922_180714_jt.jpg"></div>A Roof for All</a></li></ul></li></ul><hr class="navbar--linebreak"><ul class="navbar--footer"><li class="nav-item-footer"><a class="" href="/en_GB/contact/index.html">Contact</a></li><li class="nav-item-footer"><a class="" href="/en_GB/jobs/index.html">Jobs</a></li><li class="nav-item-footer"><a class="" href="/en_GB/media/index.html">Media</a></li><li class="nav-item-footer"><a class="" href="/en_GB/about_wimbledon/privacy.html">Privacy</a></li></ul><div class="navbar--social"><div class="navbar--social-button"><div class="share-popup hide"><div class="share-box-arrow bottom"></div><div class="share-icons"><i class="icon-facebook" title="Facebook"></i><i class="icon-twitter" title="Twitter"></i><i class="icon-instagram" title="Instagram"></i><i class="icon-youtube" title="YouTube"></i><i class="icon-wechat" title="WeChat"></i><i class="icon-weibo" title="Weibo"></i></div></div><div class="navbar--social-button-wrapper ${clicked}"><i class="icon-share"></i><div class="navbar--social-button-label">SOCIAL</div></div></div><div class="navbar--social-bar"><div class="share-bar black"><div class="share-bar-icons"><i class="icon-facebook external" title="Facebook"></i><i class="icon-twitter external" title="Twitter"></i><i class="icon-instagram external" title="Instagram"></i><i class="icon-youtube external" title="YouTube"></i><i class="icon-wechat external" title="WeChat"></i><i class="icon-weibo external" title="Weibo"></i></div></div></div></div></div></div></div><div class="background-lightbox"></div></nav><div class="page-header scores fit-width"><div class="backgroundSpace"><span><img src="/assets/images/headers/scores_header.jpg"></span></div><div class="backgroundImage scrolled"><div class="bg-holder"></div></div></div><div class="content-main draws"><div class="column-layout no-padding"><div class="header"><div class="item left"><div class="print"><a href="/en_GB/scores/draws/2019_LS_draw.pdf" class="white download" target="_blank"><i class="icon-pdf"></i></a></div></div><div class="item middle"><div class="scores-select-menu"><div class="select-menu"><button class="title"><span class="menu-text">Ladies' Singles</span><span class="menu-arrow"> ▾</span></button><div class="select-menu-dropdown "><button class="option"><i class="icon-check"></i><span class="option-name">Gentlemen's Singles</span></button><button class="option clicked"><i class="icon-check"></i><span class="option-name">Ladies' Singles</span></button><button class="option"><i class="icon-check"></i><span class="option-name">Gentlemen's Doubles</span></button><button class="option"><i class="icon-check"></i><span class="option-name">Ladies' Doubles</span></button><button class="option"><i class="icon-check"></i><span class="option-name">Mixed Doubles</span></button><button class="option"><i class="icon-check"></i><span class="option-name">Gentlemen's Wheelchair Singles</span></button><button class="option"><i class="icon-check"></i><span class="option-name">Ladies' Wheelchair Singles</span></button><button class="option"><i class="icon-check"></i><span class="option-name">Gentlemen's Wheelchair Doubles</span></button><button class="option"><i class="icon-check"></i><span class="option-name">Ladies' Wheelchair Doubles</span></button><button class="option"><i class="icon-check"></i><span class="option-name">Quad Wheelchair Singles</span></button><button class="option"><i class="icon-check"></i><span class="option-name">Quad Wheelchair Doubles</span></button><button class="option"><i class="icon-check"></i><span class="option-name">Boys' Singles</span></button><button class="option"><i class="icon-check"></i><span class="option-name">Girls' Singles</span></button><button class="option"><i class="icon-check"></i><span class="option-name">Boys' Doubles</span></button><button class="option"><i class="icon-check"></i><span class="option-name">Girls' Doubles</span></button><button class="option"><i class="icon-check"></i><span class="option-name">Gentlemen's Qualifying Singles</span></button><button class="option"><i class="icon-check"></i><span class="option-name">Ladies' Qualifying Singles</span></button><button class="option"><i class="icon-check"></i><span class="option-name">Boys' Qualifying Singles</span></button><button class="option"><i class="icon-check"></i><span class="option-name">Girls' Qualifying Singles</span></button></div></div></div></div><div class="item right"><div class="favorites-toggle "><span class="favorite-label">Your Players</span></div></div></div></div><div data-dna="draws-nav-base" class="column-layout"><div class="draws-nav"><div class="draws-nav-column-titles"><div class="title-buffer"></div><div class="round1"><span class="long">First Round</span><span class="short">1R</span></div><div class="round2"><span class="long">Second Round</span><span class="short">2R</span></div><div class="round3"><span class="long">Third Round</span><span class="short">3R</span></div><div class="round4"><span class="long">Fourth Round</span><span class="short">4R</span></div><div class="roundQ"><span class="long">Quarter-Finals</span><span class="short">QF</span></div><div class="roundS"><span class="long">Semi-Finals</span><span class="short">SF</span></div><div class="roundF"><span class="long">Final</span><span class="short">F</span></div><div class="title-buffer"></div></div><div class="draws-nav-chart"><i class="icon-left-arrow"></i><div class="draws-nav-chart-bracket"><div class="bracket-buffer"></div><div class="bracket-round s4l12"><div class="sub-round-container "><div class="line"></div><div class="line"></div><div class="line"></div></div><div class="sub-round-container "><div class="line"></div><div class="line"></div><div class="line"></div></div><div class="sub-round-container "><div class="line"></div><div class="line"></div><div class="line"></div></div><div class="sub-round-container "><div class="line"></div><div class="line"></div><div class="line"></div></div></div><div class="bracket-round s2l10"><div class="sub-round-container clicked"><div class="line"></div><div class="line"></div><div class="line"></div><div class="line"></div><div class="line"></div></div><div class="sub-round-container "><div class="line"></div><div class="line"></div><div class="line"></div><div class="line"></div><div class="line"></div></div></div><div class="bracket-round s1l10"><div class="sub-round-container "><div class="line"></div><div class="line"></div><div class="line"></div><div class="line"></div><div class="line"></div><div class="line"></div><div class="line"></div><div class="line"></div><div class="line"></div><div class="line"></div></div></div><div class="bracket-round s1l8"><div class="sub-round-container "><div class="line"></div><div class="line"></div><div class="line"></div><div class="line"></div><div class="line"></div><div class="line"></div><div class="line"></div><div class="line"></div></div></div><div class="bracket-round s1l4"><div class="sub-round-container "><div class="line"></div><div class="line"></div><div class="line"></div><div class="line"></div></div></div><div class="bracket-round s1l2"><div class="sub-round-container "><div class="line"></div><div class="line"></div></div></div><div class="bracket-round s1l1"><div class="sub-round-container "><div class="line"></div></div></div><div class="bracket-buffer"></div></div><i class="icon-right-arrow"></i></div></div></div><div class="column-layout draws-page"><div class="drawsList draws"><div><div class="roundGroup columnA draw-LS-round2"><h3>Second Round</h3><div class="drawGroup   "><div><div class="match-box match-box-draws " data-dna="match-box-draws-page" data-match="2201"><div class="match-status"><div class="green-border"></div><div class="team-info team-one singles "><div class="team-name"><div class="member-one "><div class="flag"><img alt="AUS" src="/assets/images/flags/AUS_sm.gif"></div><div class="name"><a class="" href="/en_GB/players/overview/wta318033.html">A. Barty</a></div><div class="seed ">1</div></div><div class="member-two "><div class="flag"><img src="/assets/images/flags/null_sm.gif"></div><div class="name"></div><div class="seed ">1</div></div></div><div class="crticon winner"><i class="icon-check"></i><i class="icon-ballSolid"></i></div><div class="match-results"><div class="results-wrapper"><div class="set set1"><span class="scores">6<span class="tiebreak"></span></span></div><div class="set set2"><span class="scores">6<span class="tiebreak"></span></span></div><div class="set set3"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set4"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set5"><span class="scores"><span class="tiebreak"></span></span></div></div></div></div><div class="results-info"><div class="results-info-pts">PTS</div><div class="results-info-set">1</div><div class="results-info-set">2</div><div class="results-info-set">3</div><div class="results-info-set">4</div><div class="results-info-set">5</div></div><div class="team-info team-two singles "><div class="team-name"><div class="member-one "><div class="flag"><img alt="BEL" src="/assets/images/flags/BEL_sm.gif"></div><div class="name"><a class="" href="/en_GB/players/overview/wta317819.html">A. Van Uytvanck</a></div><div class="seed hide"></div></div><div class="member-two "><div class="flag"><img src="/assets/images/flags/null_sm.gif"></div><div class="name"></div><div class="seed hide"></div></div></div><div class="crticon"><i class="icon-check"></i><i class="icon-ballSolid"></i></div><div class="match-results"><div class="results-wrapper"><div class="set set1"><span class="scores">1<span class="tiebreak"></span></span></div><div class="set set2"><span class="scores">3<span class="tiebreak"></span></span></div><div class="set set3"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set4"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set5"><span class="scores"><span class="tiebreak"></span></span></div></div></div></div></div><div class="match-box-buttons"><div class="generic-button_wrapper"><div class="generic-button compact watch-and-read" style="width: 100%;"><div class="content">Watch &amp; Read</div><div class="border"></div></div></div><div class="generic-button_wrapper"><a class="" href="/en_GB/scores/stats/2201.html"><div class="generic-button compact slamtracker-stats" style="width: 100%;"><div class="content">Stats by Slamtracker</div><div class="border"></div></div></a></div></div></div></div></div><div class="drawGroup   "><div><div class="match-box match-box-draws " data-dna="match-box-draws-page" data-match="2202"><div class="match-status"><div class="green-border"></div><div class="team-info team-one singles "><div class="team-name"><div class="member-one "><div class="flag"><img alt="GBR" src="/assets/images/flags/GBR_sm.gif"></div><div class="name"><a class="" href="/en_GB/players/overview/wta319489.html">H. Dart</a></div><div class="seed hide"></div></div><div class="member-two "><div class="flag"><img src="/assets/images/flags/null_sm.gif"></div><div class="name"></div><div class="seed hide"></div></div></div><div class="crticon winner"><i class="icon-check"></i><i class="icon-ballSolid"></i></div><div class="match-results"><div class="results-wrapper"><div class="set set1"><span class="scores">7<span class="tiebreak">7</span></span></div><div class="set set2"><span class="scores">3<span class="tiebreak"></span></span></div><div class="set set3"><span class="scores">6<span class="tiebreak"></span></span></div><div class="set set4"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set5"><span class="scores"><span class="tiebreak"></span></span></div></div></div></div><div class="results-info"><div class="results-info-pts">PTS</div><div class="results-info-set">1</div><div class="results-info-set">2</div><div class="results-info-set">3</div><div class="results-info-set">4</div><div class="results-info-set">5</div></div><div class="team-info team-two singles "><div class="team-name"><div class="member-one "><div class="flag"><img alt="BRA" src="/assets/images/flags/BRA_sm.gif"></div><div class="name"><a class="" href="/en_GB/players/overview/wta318176.html">B. Haddad Maia</a></div><div class="seed hide"></div></div><div class="member-two "><div class="flag"><img src="/assets/images/flags/null_sm.gif"></div><div class="name"></div><div class="seed hide"></div></div></div><div class="crticon"><i class="icon-check"></i><i class="icon-ballSolid"></i></div><div class="match-results"><div class="results-wrapper"><div class="set set1"><span class="scores">6<span class="tiebreak">4</span></span></div><div class="set set2"><span class="scores">6<span class="tiebreak"></span></span></div><div class="set set3"><span class="scores">1<span class="tiebreak"></span></span></div><div class="set set4"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set5"><span class="scores"><span class="tiebreak"></span></span></div></div></div></div></div><div class="match-box-buttons"><div class="generic-button_wrapper"><div class="generic-button compact watch-and-read" style="width: 100%;"><div class="content">Watch &amp; Read</div><div class="border"></div></div></div><div class="generic-button_wrapper"><a class="" href="/en_GB/scores/stats/2202.html"><div class="generic-button compact slamtracker-stats" style="width: 100%;"><div class="content">Stats by Slamtracker</div><div class="border"></div></div></a></div></div></div></div></div><div class="drawGroup   "><div><div class="match-box match-box-draws " data-dna="match-box-draws-page" data-match="2203"><div class="match-status"><div class="green-border"></div><div class="team-info team-one singles "><div class="team-name"><div class="member-one "><div class="flag"><img alt="USA" src="/assets/images/flags/USA_sm.gif"></div><div class="name"><a class="" href="/en_GB/players/overview/wta312850.html">A. Riske</a></div><div class="seed hide"></div></div><div class="member-two "><div class="flag"><img src="/assets/images/flags/null_sm.gif"></div><div class="name"></div><div class="seed hide"></div></div></div><div class="crticon winner"><i class="icon-check"></i><i class="icon-ballSolid"></i></div><div class="match-results"><div class="results-wrapper"><div class="set set1"><span class="scores">6<span class="tiebreak"></span></span></div><div class="set set2"><span class="scores">6<span class="tiebreak">3</span></span></div><div class="set set3"><span class="scores">9<span class="tiebreak"></span></span></div><div class="set set4"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set5"><span class="scores"><span class="tiebreak"></span></span></div></div></div></div><div class="results-info"><div class="results-info-pts">PTS</div><div class="results-info-set">1</div><div class="results-info-set">2</div><div class="results-info-set">3</div><div class="results-info-set">4</div><div class="results-info-set">5</div></div><div class="team-info team-two singles "><div class="team-name"><div class="member-one "><div class="flag"><img alt="SRB" src="/assets/images/flags/SRB_sm.gif"></div><div class="name"><a class="" href="/en_GB/players/overview/wta320360.html">I. Jorovic</a></div><div class="seed hide"></div></div><div class="member-two "><div class="flag"><img src="/assets/images/flags/null_sm.gif"></div><div class="name"></div><div class="seed hide"></div></div></div><div class="crticon"><i class="icon-check"></i><i class="icon-ballSolid"></i></div><div class="match-results"><div class="results-wrapper"><div class="set set1"><span class="scores">2<span class="tiebreak"></span></span></div><div class="set set2"><span class="scores">7<span class="tiebreak">7</span></span></div><div class="set set3"><span class="scores">7<span class="tiebreak"></span></span></div><div class="set set4"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set5"><span class="scores"><span class="tiebreak"></span></span></div></div></div></div></div><div class="match-box-buttons"><div class="generic-button_wrapper"><div class="generic-button compact watch-and-read" style="width: 100%;"><div class="content">Watch &amp; Read</div><div class="border"></div></div></div><div class="generic-button_wrapper"><a class="" href="/en_GB/scores/stats/2203.html"><div class="generic-button compact slamtracker-stats" style="width: 100%;"><div class="content">Stats by Slamtracker</div><div class="border"></div></div></a></div></div></div></div></div><div class="drawGroup   "><div><div class="match-box match-box-draws " data-dna="match-box-draws-page" data-match="2204"><div class="match-status"><div class="green-border"></div><div class="team-info team-one singles "><div class="team-name"><div class="member-one "><div class="flag"><img alt="EST" src="/assets/images/flags/EST_sm.gif"></div><div class="name"><a class="" href="/en_GB/players/overview/wta110536.html">K. Kanepi</a></div><div class="seed hide"></div></div><div class="member-two "><div class="flag"><img src="/assets/images/flags/null_sm.gif"></div><div class="name"></div><div class="seed hide"></div></div></div><div class="crticon"><i class="icon-check"></i><i class="icon-ballSolid"></i></div><div class="match-results"><div class="results-wrapper"><div class="set set1"><span class="scores">3<span class="tiebreak"></span></span></div><div class="set set2"><span class="scores">1<span class="tiebreak"></span></span></div><div class="set set3"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set4"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set5"><span class="scores"><span class="tiebreak"></span></span></div></div></div></div><div class="results-info"><div class="results-info-pts">PTS</div><div class="results-info-set">1</div><div class="results-info-set">2</div><div class="results-info-set">3</div><div class="results-info-set">4</div><div class="results-info-set">5</div></div><div class="team-info team-two singles "><div class="team-name"><div class="member-one "><div class="flag"><img alt="SUI" src="/assets/images/flags/SUI_sm.gif"></div><div class="name"><a class="" href="/en_GB/players/overview/wta319001.html">B. Bencic</a></div><div class="seed ">13</div></div><div class="member-two "><div class="flag"><img src="/assets/images/flags/null_sm.gif"></div><div class="name"></div><div class="seed ">13</div></div></div><div class="crticon winner"><i class="icon-check"></i><i class="icon-ballSolid"></i></div><div class="match-results"><div class="results-wrapper"><div class="set set1"><span class="scores">6<span class="tiebreak"></span></span></div><div class="set set2"><span class="scores">6<span class="tiebreak"></span></span></div><div class="set set3"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set4"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set5"><span class="scores"><span class="tiebreak"></span></span></div></div></div></div></div><div class="match-box-buttons"><div class="generic-button_wrapper"><div class="generic-button compact watch-and-read" style="width: 100%;"><div class="content">Watch &amp; Read</div><div class="border"></div></div></div><div class="generic-button_wrapper"><a class="" href="/en_GB/scores/stats/2204.html"><div class="generic-button compact slamtracker-stats" style="width: 100%;"><div class="content">Stats by Slamtracker</div><div class="border"></div></div></a></div></div></div></div></div><div class="drawGroup   "><div><div class="match-box match-box-draws " data-dna="match-box-draws-page" data-match="2205"><div class="match-status"><div class="green-border"></div><div class="team-info team-one singles "><div class="team-name"><div class="member-one "><div class="flag"><img alt="USA" src="/assets/images/flags/USA_sm.gif"></div><div class="name"><a class="" href="/en_GB/players/overview/wta230234.html">S. Williams</a></div><div class="seed ">11</div></div><div class="member-two "><div class="flag"><img src="/assets/images/flags/null_sm.gif"></div><div class="name"></div><div class="seed ">11</div></div></div><div class="crticon winner"><i class="icon-check"></i><i class="icon-ballSolid"></i></div><div class="match-results"><div class="results-wrapper"><div class="set set1"><span class="scores">2<span class="tiebreak"></span></span></div><div class="set set2"><span class="scores">6<span class="tiebreak"></span></span></div><div class="set set3"><span class="scores">6<span class="tiebreak"></span></span></div><div class="set set4"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set5"><span class="scores"><span class="tiebreak"></span></span></div></div></div></div><div class="results-info"><div class="results-info-pts">PTS</div><div class="results-info-set">1</div><div class="results-info-set">2</div><div class="results-info-set">3</div><div class="results-info-set">4</div><div class="results-info-set">5</div></div><div class="team-info team-two singles "><div class="team-name"><div class="member-one "><div class="flag"><img alt="SLO" src="/assets/images/flags/SLO_sm.gif"></div><div class="name"><a class="" href="/en_GB/players/overview/wta324702.html">K. Juvan</a></div><div class="seed hide"></div></div><div class="member-two "><div class="flag"><img src="/assets/images/flags/null_sm.gif"></div><div class="name"></div><div class="seed hide"></div></div></div><div class="crticon"><i class="icon-check"></i><i class="icon-ballSolid"></i></div><div class="match-results"><div class="results-wrapper"><div class="set set1"><span class="scores">6<span class="tiebreak"></span></span></div><div class="set set2"><span class="scores">2<span class="tiebreak"></span></span></div><div class="set set3"><span class="scores">4<span class="tiebreak"></span></span></div><div class="set set4"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set5"><span class="scores"><span class="tiebreak"></span></span></div></div></div></div></div><div class="match-box-buttons"><div class="generic-button_wrapper"><div class="generic-button compact watch-and-read" style="width: 100%;"><div class="content">Watch &amp; Read</div><div class="border"></div></div></div><div class="generic-button_wrapper"><a class="" href="/en_GB/scores/stats/2205.html"><div class="generic-button compact slamtracker-stats" style="width: 100%;"><div class="content">Stats by Slamtracker</div><div class="border"></div></div></a></div></div></div></div></div><div class="drawGroup   "><div><div class="match-box match-box-draws " data-dna="match-box-draws-page" data-match="2206"><div class="match-status"><div class="green-border"></div><div class="team-info team-one singles "><div class="team-name"><div class="member-one "><div class="flag"><img alt="RUS" src="/assets/images/flags/RUS_sm.gif"></div><div class="name"><a class="" href="/en_GB/players/overview/wta318913.html">V. Flink</a></div><div class="seed hide"></div></div><div class="member-two "><div class="flag"><img src="/assets/images/flags/null_sm.gif"></div><div class="name"></div><div class="seed hide"></div></div></div><div class="crticon"><i class="icon-check"></i><i class="icon-ballSolid"></i></div><div class="match-results"><div class="results-wrapper"><div class="set set1"><span class="scores">1<span class="tiebreak"></span></span></div><div class="set set2"><span class="scores">4<span class="tiebreak"></span></span></div><div class="set set3"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set4"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set5"><span class="scores"><span class="tiebreak"></span></span></div></div></div></div><div class="results-info"><div class="results-info-pts">PTS</div><div class="results-info-set">1</div><div class="results-info-set">2</div><div class="results-info-set">3</div><div class="results-info-set">4</div><div class="results-info-set">5</div></div><div class="team-info team-two singles "><div class="team-name"><div class="member-one "><div class="flag"><img alt="GER" src="/assets/images/flags/GER_sm.gif"></div><div class="name"><a class="" href="/en_GB/players/overview/wta313381.html">J. Goerges</a></div><div class="seed ">18</div></div><div class="member-two "><div class="flag"><img src="/assets/images/flags/null_sm.gif"></div><div class="name"></div><div class="seed ">18</div></div></div><div class="crticon winner"><i class="icon-check"></i><i class="icon-ballSolid"></i></div><div class="match-results"><div class="results-wrapper"><div class="set set1"><span class="scores">6<span class="tiebreak"></span></span></div><div class="set set2"><span class="scores">6<span class="tiebreak"></span></span></div><div class="set set3"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set4"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set5"><span class="scores"><span class="tiebreak"></span></span></div></div></div></div></div><div class="match-box-buttons"><div class="generic-button_wrapper"><div class="generic-button compact watch-and-read" style="width: 100%;"><div class="content">Watch &amp; Read</div><div class="border"></div></div></div><div class="generic-button_wrapper"><a class="" href="/en_GB/scores/stats/2206.html"><div class="generic-button compact slamtracker-stats" style="width: 100%;"><div class="content">Stats by Slamtracker</div><div class="border"></div></div></a></div></div></div></div></div><div class="drawGroup   "><div><div class="match-box match-box-draws " data-dna="match-box-draws-page" data-match="2207"><div class="match-status"><div class="green-border"></div><div class="team-info team-one singles "><div class="team-name"><div class="member-one "><div class="flag"><img alt="ESP" src="/assets/images/flags/ESP_sm.gif"></div><div class="name"><a class="" href="/en_GB/players/overview/wta311338.html">C. Suarez Navarro</a></div><div class="seed ">30</div></div><div class="member-two "><div class="flag"><img src="/assets/images/flags/null_sm.gif"></div><div class="name"></div><div class="seed ">30</div></div></div><div class="crticon winner"><i class="icon-check"></i><i class="icon-ballSolid"></i></div><div class="match-results"><div class="results-wrapper"><div class="set set1"><span class="scores">7<span class="tiebreak">7</span></span></div><div class="set set2"><span class="scores">7<span class="tiebreak">7</span></span></div><div class="set set3"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set4"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set5"><span class="scores"><span class="tiebreak"></span></span></div></div></div></div><div class="results-info"><div class="results-info-pts">PTS</div><div class="results-info-set">1</div><div class="results-info-set">2</div><div class="results-info-set">3</div><div class="results-info-set">4</div><div class="results-info-set">5</div></div><div class="team-info team-two singles "><div class="team-name"><div class="member-one "><div class="flag"><img alt="FRA" src="/assets/images/flags/FRA_sm.gif"></div><div class="name"><a class="" href="/en_GB/players/overview/wta160515.html">P. Parmentier</a></div><div class="seed hide"></div></div><div class="member-two "><div class="flag"><img src="/assets/images/flags/null_sm.gif"></div><div class="name"></div><div class="seed hide"></div></div></div><div class="crticon"><i class="icon-check"></i><i class="icon-ballSolid"></i></div><div class="match-results"><div class="results-wrapper"><div class="set set1"><span class="scores">6<span class="tiebreak">2</span></span></div><div class="set set2"><span class="scores">6<span class="tiebreak">4</span></span></div><div class="set set3"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set4"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set5"><span class="scores"><span class="tiebreak"></span></span></div></div></div></div></div><div class="match-box-buttons"><div class="generic-button_wrapper"><div class="generic-button compact watch-and-read" style="width: 100%;"><div class="content">Watch &amp; Read</div><div class="border"></div></div></div><div class="generic-button_wrapper"><a class="" href="/en_GB/scores/stats/2207.html"><div class="generic-button compact slamtracker-stats" style="width: 100%;"><div class="content">Stats by Slamtracker</div><div class="border"></div></div></a></div></div></div></div></div><div class="drawGroup   "><div><div class="match-box match-box-draws " data-dna="match-box-draws-page" data-match="2208"><div class="match-status"><div class="green-border"></div><div class="team-info team-one singles "><div class="team-name"><div class="member-one "><div class="flag"><img alt="USA" src="/assets/images/flags/USA_sm.gif"></div><div class="name"><a class="" href="/en_GB/players/overview/wta317414.html">L. Davis</a></div><div class="seed hide"></div></div><div class="member-two "><div class="flag"><img src="/assets/images/flags/null_sm.gif"></div><div class="name"></div><div class="seed hide"></div></div></div><div class="crticon winner"><i class="icon-check"></i><i class="icon-ballSolid"></i></div><div class="match-results"><div class="results-wrapper"><div class="set set1"><span class="scores">2<span class="tiebreak"></span></span></div><div class="set set2"><span class="scores">6<span class="tiebreak"></span></span></div><div class="set set3"><span class="scores">6<span class="tiebreak"></span></span></div><div class="set set4"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set5"><span class="scores"><span class="tiebreak"></span></span></div></div></div></div><div class="results-info"><div class="results-info-pts">PTS</div><div class="results-info-set">1</div><div class="results-info-set">2</div><div class="results-info-set">3</div><div class="results-info-set">4</div><div class="results-info-set">5</div></div><div class="team-info team-two singles "><div class="team-name"><div class="member-one "><div class="flag"><img alt="GER" src="/assets/images/flags/GER_sm.gif"></div><div class="name"><a class="" href="/en_GB/players/overview/wta311470.html">A. Kerber</a></div><div class="seed ">5</div></div><div class="member-two "><div class="flag"><img src="/assets/images/flags/null_sm.gif"></div><div class="name"></div><div class="seed ">5</div></div></div><div class="crticon"><i class="icon-check"></i><i class="icon-ballSolid"></i></div><div class="match-results"><div class="results-wrapper"><div class="set set1"><span class="scores">6<span class="tiebreak"></span></span></div><div class="set set2"><span class="scores">2<span class="tiebreak"></span></span></div><div class="set set3"><span class="scores">1<span class="tiebreak"></span></span></div><div class="set set4"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set5"><span class="scores"><span class="tiebreak"></span></span></div></div></div></div></div><div class="match-box-buttons"><div class="generic-button_wrapper"><div class="generic-button compact watch-and-read" style="width: 100%;"><div class="content">Watch &amp; Read</div><div class="border"></div></div></div><div class="generic-button_wrapper"><a class="" href="/en_GB/scores/stats/2208.html"><div class="generic-button compact slamtracker-stats" style="width: 100%;"><div class="content">Stats by Slamtracker</div><div class="border"></div></div></a></div></div></div></div></div><div class="drawGroup   "><div><div class="match-box match-box-draws " data-dna="match-box-draws-page" data-match="2209"><div class="match-status"><div class="green-border"></div><div class="team-info team-one singles "><div class="team-name"><div class="member-one "><div class="flag"><img alt="NED" src="/assets/images/flags/NED_sm.gif"></div><div class="name"><a class="" href="/en_GB/players/overview/wta314584.html">K. Bertens</a></div><div class="seed ">4</div></div><div class="member-two "><div class="flag"><img src="/assets/images/flags/null_sm.gif"></div><div class="name"></div><div class="seed ">4</div></div></div><div class="crticon winner"><i class="icon-check"></i><i class="icon-ballSolid"></i></div><div class="match-results"><div class="results-wrapper"><div class="set set1"><span class="scores">3<span class="tiebreak"></span></span></div><div class="set set2"><span class="scores">7<span class="tiebreak">7</span></span></div><div class="set set3"><span class="scores">6<span class="tiebreak"></span></span></div><div class="set set4"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set5"><span class="scores"><span class="tiebreak"></span></span></div></div></div></div><div class="results-info"><div class="results-info-pts">PTS</div><div class="results-info-set">1</div><div class="results-info-set">2</div><div class="results-info-set">3</div><div class="results-info-set">4</div><div class="results-info-set">5</div></div><div class="team-info team-two singles "><div class="team-name"><div class="member-one "><div class="flag"><img alt="USA" src="/assets/images/flags/USA_sm.gif"></div><div class="name"><a class="" href="/en_GB/players/overview/wta318609.html">T. Townsend</a></div><div class="seed hide"></div></div><div class="member-two "><div class="flag"><img src="/assets/images/flags/null_sm.gif"></div><div class="name"></div><div class="seed hide"></div></div></div><div class="crticon"><i class="icon-check"></i><i class="icon-ballSolid"></i></div><div class="match-results"><div class="results-wrapper"><div class="set set1"><span class="scores">6<span class="tiebreak"></span></span></div><div class="set set2"><span class="scores">6<span class="tiebreak">5</span></span></div><div class="set set3"><span class="scores">2<span class="tiebreak"></span></span></div><div class="set set4"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set5"><span class="scores"><span class="tiebreak"></span></span></div></div></div></div></div><div class="match-box-buttons"><div class="generic-button_wrapper"><div class="generic-button compact watch-and-read" style="width: 100%;"><div class="content">Watch &amp; Read</div><div class="border"></div></div></div><div class="generic-button_wrapper"><a class="" href="/en_GB/scores/stats/2209.html"><div class="generic-button compact slamtracker-stats" style="width: 100%;"><div class="content">Stats by Slamtracker</div><div class="border"></div></div></a></div></div></div></div></div><div class="drawGroup   "><div><div class="match-box match-box-draws " data-dna="match-box-draws-page" data-match="2210"><div class="match-status"><div class="green-border"></div><div class="team-info team-one singles "><div class="team-name"><div class="member-one "><div class="flag"><img alt="GER" src="/assets/images/flags/GER_sm.gif"></div><div class="name"><a class="" href="/en_GB/players/overview/wta310926.html">L. Siegemund</a></div><div class="seed hide"></div></div><div class="member-two "><div class="flag"><img src="/assets/images/flags/null_sm.gif"></div><div class="name"></div><div class="seed hide"></div></div></div><div class="crticon"><i class="icon-check"></i><i class="icon-ballSolid"></i></div><div class="match-results"><div class="results-wrapper"><div class="set set1"><span class="scores">3<span class="tiebreak"></span></span></div><div class="set set2"><span class="scores">5<span class="tiebreak"></span></span></div><div class="set set3"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set4"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set5"><span class="scores"><span class="tiebreak"></span></span></div></div></div></div><div class="results-info"><div class="results-info-pts">PTS</div><div class="results-info-set">1</div><div class="results-info-set">2</div><div class="results-info-set">3</div><div class="results-info-set">4</div><div class="results-info-set">5</div></div><div class="team-info team-two singles "><div class="team-name"><div class="member-one "><div class="flag"><img alt="CZE" src="/assets/images/flags/CZE_sm.gif"></div><div class="name"><a class="" href="/en_GB/players/overview/wta190879.html">B. Strycova</a></div><div class="seed hide"></div></div><div class="member-two "><div class="flag"><img src="/assets/images/flags/null_sm.gif"></div><div class="name"></div><div class="seed hide"></div></div></div><div class="crticon winner"><i class="icon-check"></i><i class="icon-ballSolid"></i></div><div class="match-results"><div class="results-wrapper"><div class="set set1"><span class="scores">6<span class="tiebreak"></span></span></div><div class="set set2"><span class="scores">7<span class="tiebreak"></span></span></div><div class="set set3"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set4"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set5"><span class="scores"><span class="tiebreak"></span></span></div></div></div></div></div><div class="match-box-buttons"><div class="generic-button_wrapper"><div class="generic-button compact watch-and-read" style="width: 100%;"><div class="content">Watch &amp; Read</div><div class="border"></div></div></div><div class="generic-button_wrapper"><a class="" href="/en_GB/scores/stats/2210.html"><div class="generic-button compact slamtracker-stats" style="width: 100%;"><div class="content">Stats by Slamtracker</div><div class="border"></div></div></a></div></div></div></div></div><div class="drawGroup   "><div><div class="match-box match-box-draws " data-dna="match-box-draws-page" data-match="2211"><div class="match-status"><div class="green-border"></div><div class="team-info team-one singles "><div class="team-name"><div class="member-one "><div class="flag"><img alt="BEL" src="/assets/images/flags/BEL_sm.gif"></div><div class="name"><a class="" href="/en_GB/players/overview/wta317964.html">E. Mertens</a></div><div class="seed ">21</div></div><div class="member-two "><div class="flag"><img src="/assets/images/flags/null_sm.gif"></div><div class="name"></div><div class="seed ">21</div></div></div><div class="crticon winner"><i class="icon-check"></i><i class="icon-ballSolid"></i></div><div class="match-results"><div class="results-wrapper"><div class="set set1"><span class="scores">7<span class="tiebreak"></span></span></div><div class="set set2"><span class="scores">6<span class="tiebreak"></span></span></div><div class="set set3"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set4"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set5"><span class="scores"><span class="tiebreak"></span></span></div></div></div></div><div class="results-info"><div class="results-info-pts">PTS</div><div class="results-info-set">1</div><div class="results-info-set">2</div><div class="results-info-set">3</div><div class="results-info-set">4</div><div class="results-info-set">5</div></div><div class="team-info team-two singles "><div class="team-name"><div class="member-one "><div class="flag"><img alt="ROU" src="/assets/images/flags/ROU_sm.gif"></div><div class="name"><a class="" href="/en_GB/players/overview/wta310775.html">M. Niculescu</a></div><div class="seed hide"></div></div><div class="member-two "><div class="flag"><img src="/assets/images/flags/null_sm.gif"></div><div class="name"></div><div class="seed hide"></div></div></div><div class="crticon"><i class="icon-check"></i><i class="icon-ballSolid"></i></div><div class="match-results"><div class="results-wrapper"><div class="set set1"><span class="scores">5<span class="tiebreak"></span></span></div><div class="set set2"><span class="scores">0<span class="tiebreak"></span></span></div><div class="set set3"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set4"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set5"><span class="scores"><span class="tiebreak"></span></span></div></div></div></div></div><div class="match-box-buttons"><div class="generic-button_wrapper"><div class="generic-button compact watch-and-read" style="width: 100%;"><div class="content">Watch &amp; Read</div><div class="border"></div></div></div><div class="generic-button_wrapper"><a class="" href="/en_GB/scores/stats/2211.html"><div class="generic-button compact slamtracker-stats" style="width: 100%;"><div class="content">Stats by Slamtracker</div><div class="border"></div></div></a></div></div></div></div></div><div class="drawGroup   "><div><div class="match-box match-box-draws " data-dna="match-box-draws-page" data-match="2212"><div class="match-status"><div class="green-border"></div><div class="team-info team-one singles "><div class="team-name"><div class="member-one "><div class="flag"><img alt="SLO" src="/assets/images/flags/SLO_sm.gif"></div><div class="name"><a class="" href="/en_GB/players/overview/wta323079.html">T. Zidansek</a></div><div class="seed hide"></div></div><div class="member-two "><div class="flag"><img src="/assets/images/flags/null_sm.gif"></div><div class="name"></div><div class="seed hide"></div></div></div><div class="crticon"><i class="icon-check"></i><i class="icon-ballSolid"></i></div><div class="match-results"><div class="results-wrapper"><div class="set set1"><span class="scores">1<span class="tiebreak"></span></span></div><div class="set set2"><span class="scores">2<span class="tiebreak"></span></span></div><div class="set set3"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set4"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set5"><span class="scores"><span class="tiebreak"></span></span></div></div></div></div><div class="results-info"><div class="results-info-pts">PTS</div><div class="results-info-set">1</div><div class="results-info-set">2</div><div class="results-info-set">3</div><div class="results-info-set">4</div><div class="results-info-set">5</div></div><div class="team-info team-two singles "><div class="team-name"><div class="member-one "><div class="flag"><img alt="CHN" src="/assets/images/flags/CHN_sm.gif"></div><div class="name"><a class="" href="/en_GB/players/overview/wta314429.html">Q. Wang</a></div><div class="seed ">15</div></div><div class="member-two "><div class="flag"><img src="/assets/images/flags/null_sm.gif"></div><div class="name"></div><div class="seed ">15</div></div></div><div class="crticon winner"><i class="icon-check"></i><i class="icon-ballSolid"></i></div><div class="match-results"><div class="results-wrapper"><div class="set set1"><span class="scores">6<span class="tiebreak"></span></span></div><div class="set set2"><span class="scores">6<span class="tiebreak"></span></span></div><div class="set set3"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set4"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set5"><span class="scores"><span class="tiebreak"></span></span></div></div></div></div></div><div class="match-box-buttons"><div class="generic-button_wrapper"><div class="generic-button compact watch-and-read" style="width: 100%;"><div class="content">Watch &amp; Read</div><div class="border"></div></div></div><div class="generic-button_wrapper"><a class="" href="/en_GB/scores/stats/2212.html"><div class="generic-button compact slamtracker-stats" style="width: 100%;"><div class="content">Stats by Slamtracker</div><div class="border"></div></div></a></div></div></div></div></div><div class="drawGroup   "><div><div class="match-box match-box-draws " data-dna="match-box-draws-page" data-match="2213"><div class="match-status"><div class="green-border"></div><div class="team-info team-one singles "><div class="team-name"><div class="member-one "><div class="flag"><img alt="USA" src="/assets/images/flags/USA_sm.gif"></div><div class="name"><a class="" href="/en_GB/players/overview/wta315683.html">S. Stephens</a></div><div class="seed ">9</div></div><div class="member-two "><div class="flag"><img src="/assets/images/flags/null_sm.gif"></div><div class="name"></div><div class="seed ">9</div></div></div><div class="crticon winner"><i class="icon-check"></i><i class="icon-ballSolid"></i></div><div class="match-results"><div class="results-wrapper"><div class="set set1"><span class="scores">6<span class="tiebreak"></span></span></div><div class="set set2"><span class="scores">6<span class="tiebreak"></span></span></div><div class="set set3"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set4"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set5"><span class="scores"><span class="tiebreak"></span></span></div></div></div></div><div class="results-info"><div class="results-info-pts">PTS</div><div class="results-info-set">1</div><div class="results-info-set">2</div><div class="results-info-set">3</div><div class="results-info-set">4</div><div class="results-info-set">5</div></div><div class="team-info team-two singles "><div class="team-name"><div class="member-one "><div class="flag"><img alt="CHN" src="/assets/images/flags/CHN_sm.gif"></div><div class="name"><a class="" href="/en_GB/players/overview/wta317510.html">Y. Wang</a></div><div class="seed hide"></div></div><div class="member-two "><div class="flag"><img src="/assets/images/flags/null_sm.gif"></div><div class="name"></div><div class="seed hide"></div></div></div><div class="crticon"><i class="icon-check"></i><i class="icon-ballSolid"></i></div><div class="match-results"><div class="results-wrapper"><div class="set set1"><span class="scores">0<span class="tiebreak"></span></span></div><div class="set set2"><span class="scores">2<span class="tiebreak"></span></span></div><div class="set set3"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set4"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set5"><span class="scores"><span class="tiebreak"></span></span></div></div></div></div></div><div class="match-box-buttons"><div class="generic-button_wrapper"><div class="generic-button compact watch-and-read" style="width: 100%;"><div class="content">Watch &amp; Read</div><div class="border"></div></div></div><div class="generic-button_wrapper"><a class="" href="/en_GB/scores/stats/2213.html"><div class="generic-button compact slamtracker-stats" style="width: 100%;"><div class="content">Stats by Slamtracker</div><div class="border"></div></div></a></div></div></div></div></div><div class="drawGroup   "><div><div class="match-box match-box-draws " data-dna="match-box-draws-page" data-match="2214"><div class="match-status"><div class="green-border"></div><div class="team-info team-one singles "><div class="team-name"><div class="member-one "><div class="flag"><img alt="CZE" src="/assets/images/flags/CZE_sm.gif"></div><div class="name"><a class="" href="/en_GB/players/overview/wta320301.html">K. Siniakova</a></div><div class="seed hide"></div></div><div class="member-two "><div class="flag"><img src="/assets/images/flags/null_sm.gif"></div><div class="name"></div><div class="seed hide"></div></div></div><div class="crticon"><i class="icon-check"></i><i class="icon-ballSolid"></i></div><div class="match-results"><div class="results-wrapper"><div class="set set1"><span class="scores">3<span class="tiebreak"></span></span></div><div class="set set2"><span class="scores">4<span class="tiebreak"></span></span></div><div class="set set3"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set4"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set5"><span class="scores"><span class="tiebreak"></span></span></div></div></div></div><div class="results-info"><div class="results-info-pts">PTS</div><div class="results-info-set">1</div><div class="results-info-set">2</div><div class="results-info-set">3</div><div class="results-info-set">4</div><div class="results-info-set">5</div></div><div class="team-info team-two singles "><div class="team-name"><div class="member-one "><div class="flag"><img alt="GBR" src="/assets/images/flags/GBR_sm.gif"></div><div class="name"><a class="" href="/en_GB/players/overview/wta313907.html">J. Konta</a></div><div class="seed ">19</div></div><div class="member-two "><div class="flag"><img src="/assets/images/flags/null_sm.gif"></div><div class="name"></div><div class="seed ">19</div></div></div><div class="crticon winner"><i class="icon-check"></i><i class="icon-ballSolid"></i></div><div class="match-results"><div class="results-wrapper"><div class="set set1"><span class="scores">6<span class="tiebreak"></span></span></div><div class="set set2"><span class="scores">6<span class="tiebreak"></span></span></div><div class="set set3"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set4"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set5"><span class="scores"><span class="tiebreak"></span></span></div></div></div></div></div><div class="match-box-buttons"><div class="generic-button_wrapper"><div class="generic-button compact watch-and-read" style="width: 100%;"><div class="content">Watch &amp; Read</div><div class="border"></div></div></div><div class="generic-button_wrapper"><a class="" href="/en_GB/scores/stats/2214.html"><div class="generic-button compact slamtracker-stats" style="width: 100%;"><div class="content">Stats by Slamtracker</div><div class="border"></div></div></a></div></div></div></div></div><div class="drawGroup   "><div><div class="match-box match-box-draws " data-dna="match-box-draws-page" data-match="2215"><div class="match-status"><div class="green-border"></div><div class="team-info team-one singles "><div class="team-name"><div class="member-one "><div class="flag"><img alt="USA" src="/assets/images/flags/USA_sm.gif"></div><div class="name"><a class="" href="/en_GB/players/overview/wta326384.html">A. Anisimova</a></div><div class="seed ">25</div></div><div class="member-two "><div class="flag"><img src="/assets/images/flags/null_sm.gif"></div><div class="name"></div><div class="seed ">25</div></div></div><div class="crticon"><i class="icon-check"></i><i class="icon-ballSolid"></i></div><div class="match-results"><div class="results-wrapper"><div class="set set1"><span class="scores">4<span class="tiebreak"></span></span></div><div class="set set2"><span class="scores">5<span class="tiebreak"></span></span></div><div class="set set3"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set4"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set5"><span class="scores"><span class="tiebreak"></span></span></div></div></div></div><div class="results-info"><div class="results-info-pts">PTS</div><div class="results-info-set">1</div><div class="results-info-set">2</div><div class="results-info-set">3</div><div class="results-info-set">4</div><div class="results-info-set">5</div></div><div class="team-info team-two singles "><div class="team-name"><div class="member-one "><div class="flag"><img alt="POL" src="/assets/images/flags/POL_sm.gif"></div><div class="name"><a class="" href="/en_GB/players/overview/wta315130.html">M. Linette</a></div><div class="seed hide"></div></div><div class="member-two "><div class="flag"><img src="/assets/images/flags/null_sm.gif"></div><div class="name"></div><div class="seed hide"></div></div></div><div class="crticon winner"><i class="icon-check"></i><i class="icon-ballSolid"></i></div><div class="match-results"><div class="results-wrapper"><div class="set set1"><span class="scores">6<span class="tiebreak"></span></span></div><div class="set set2"><span class="scores">7<span class="tiebreak"></span></span></div><div class="set set3"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set4"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set5"><span class="scores"><span class="tiebreak"></span></span></div></div></div></div></div><div class="match-box-buttons"><div class="generic-button_wrapper"><div class="generic-button compact watch-and-read" style="width: 100%;"><div class="content">Watch &amp; Read</div><div class="border"></div></div></div><div class="generic-button_wrapper"><a class="" href="/en_GB/scores/stats/2215.html"><div class="generic-button compact slamtracker-stats" style="width: 100%;"><div class="content">Stats by Slamtracker</div><div class="border"></div></div></a></div></div></div></div></div><div class="drawGroup   "><div><div class="match-box match-box-draws " data-dna="match-box-draws-page" data-match="2216"><div class="match-status"><div class="green-border"></div><div class="team-info team-one singles "><div class="team-name"><div class="member-one "><div class="flag"><img alt="FRA" src="/assets/images/flags/FRA_sm.gif"></div><div class="name"><a class="" href="/en_GB/players/overview/wta315616.html">K. Mladenovic</a></div><div class="seed hide"></div></div><div class="member-two "><div class="flag"><img src="/assets/images/flags/null_sm.gif"></div><div class="name"></div><div class="seed hide"></div></div></div><div class="crticon"><i class="icon-check"></i><i class="icon-ballSolid"></i></div><div class="match-results"><div class="results-wrapper"><div class="set set1"><span class="scores">5<span class="tiebreak"></span></span></div><div class="set set2"><span class="scores">2<span class="tiebreak"></span></span></div><div class="set set3"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set4"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set5"><span class="scores"><span class="tiebreak"></span></span></div></div></div></div><div class="results-info"><div class="results-info-pts">PTS</div><div class="results-info-set">1</div><div class="results-info-set">2</div><div class="results-info-set">3</div><div class="results-info-set">4</div><div class="results-info-set">5</div></div><div class="team-info team-two singles "><div class="team-name"><div class="member-one "><div class="flag"><img alt="CZE" src="/assets/images/flags/CZE_sm.gif"></div><div class="name"><a class="" href="/en_GB/players/overview/wta314206.html">P. Kvitova</a></div><div class="seed ">6</div></div><div class="member-two "><div class="flag"><img src="/assets/images/flags/null_sm.gif"></div><div class="name"></div><div class="seed ">6</div></div></div><div class="crticon winner"><i class="icon-check"></i><i class="icon-ballSolid"></i></div><div class="match-results"><div class="results-wrapper"><div class="set set1"><span class="scores">7<span class="tiebreak"></span></span></div><div class="set set2"><span class="scores">6<span class="tiebreak"></span></span></div><div class="set set3"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set4"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set5"><span class="scores"><span class="tiebreak"></span></span></div></div></div></div></div><div class="match-box-buttons"><div class="generic-button_wrapper"><div class="generic-button compact watch-and-read" style="width: 100%;"><div class="content">Watch &amp; Read</div><div class="border"></div></div></div><div class="generic-button_wrapper"><a class="" href="/en_GB/scores/stats/2216.html"><div class="generic-button compact slamtracker-stats" style="width: 100%;"><div class="content">Stats by Slamtracker</div><div class="border"></div></div></a></div></div></div></div></div></div><div class="roundGroup columnB draw-LS-round2"><h3>Third Round</h3><div class="drawGroup   "><div><div class="match-box match-box-draws " data-dna="match-box-draws-page" data-match="2301"><div class="match-status"><div class="green-border"></div><div class="team-info team-one singles "><div class="team-name"><div class="member-one "><div class="flag"><img alt="AUS" src="/assets/images/flags/AUS_sm.gif"></div><div class="name"><a class="" href="/en_GB/players/overview/wta318033.html">A. Barty</a></div><div class="seed ">1</div></div><div class="member-two "><div class="flag"><img src="/assets/images/flags/null_sm.gif"></div><div class="name"></div><div class="seed ">1</div></div></div><div class="crticon winner"><i class="icon-check"></i><i class="icon-ballSolid"></i></div><div class="match-results"><div class="results-wrapper"><div class="set set1"><span class="scores">6<span class="tiebreak"></span></span></div><div class="set set2"><span class="scores">6<span class="tiebreak"></span></span></div><div class="set set3"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set4"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set5"><span class="scores"><span class="tiebreak"></span></span></div></div></div></div><div class="results-info"><div class="results-info-pts">PTS</div><div class="results-info-set">1</div><div class="results-info-set">2</div><div class="results-info-set">3</div><div class="results-info-set">4</div><div class="results-info-set">5</div></div><div class="team-info team-two singles "><div class="team-name"><div class="member-one "><div class="flag"><img alt="GBR" src="/assets/images/flags/GBR_sm.gif"></div><div class="name"><a class="" href="/en_GB/players/overview/wta319489.html">H. Dart</a></div><div class="seed hide"></div></div><div class="member-two "><div class="flag"><img src="/assets/images/flags/null_sm.gif"></div><div class="name"></div><div class="seed hide"></div></div></div><div class="crticon"><i class="icon-check"></i><i class="icon-ballSolid"></i></div><div class="match-results"><div class="results-wrapper"><div class="set set1"><span class="scores">1<span class="tiebreak"></span></span></div><div class="set set2"><span class="scores">1<span class="tiebreak"></span></span></div><div class="set set3"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set4"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set5"><span class="scores"><span class="tiebreak"></span></span></div></div></div></div></div><div class="match-box-buttons"><div class="generic-button_wrapper"><div class="generic-button compact watch-and-read" style="width: 100%;"><div class="content">Watch &amp; Read</div><div class="border"></div></div></div><div class="generic-button_wrapper"><a class="" href="/en_GB/scores/stats/2301.html"><div class="generic-button compact slamtracker-stats" style="width: 100%;"><div class="content">Stats by Slamtracker</div><div class="border"></div></div></a></div></div></div></div></div><div class="drawGroup   "><div><div class="match-box match-box-draws " data-dna="match-box-draws-page" data-match="2302"><div class="match-status"><div class="green-border"></div><div class="team-info team-one singles "><div class="team-name"><div class="member-one "><div class="flag"><img alt="USA" src="/assets/images/flags/USA_sm.gif"></div><div class="name"><a class="" href="/en_GB/players/overview/wta312850.html">A. Riske</a></div><div class="seed hide"></div></div><div class="member-two "><div class="flag"><img src="/assets/images/flags/null_sm.gif"></div><div class="name"></div><div class="seed hide"></div></div></div><div class="crticon winner"><i class="icon-check"></i><i class="icon-ballSolid"></i></div><div class="match-results"><div class="results-wrapper"><div class="set set1"><span class="scores">4<span class="tiebreak"></span></span></div><div class="set set2"><span class="scores">6<span class="tiebreak"></span></span></div><div class="set set3"><span class="scores">6<span class="tiebreak"></span></span></div><div class="set set4"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set5"><span class="scores"><span class="tiebreak"></span></span></div></div></div></div><div class="results-info"><div class="results-info-pts">PTS</div><div class="results-info-set">1</div><div class="results-info-set">2</div><div class="results-info-set">3</div><div class="results-info-set">4</div><div class="results-info-set">5</div></div><div class="team-info team-two singles "><div class="team-name"><div class="member-one "><div class="flag"><img alt="SUI" src="/assets/images/flags/SUI_sm.gif"></div><div class="name"><a class="" href="/en_GB/players/overview/wta319001.html">B. Bencic</a></div><div class="seed ">13</div></div><div class="member-two "><div class="flag"><img src="/assets/images/flags/null_sm.gif"></div><div class="name"></div><div class="seed ">13</div></div></div><div class="crticon"><i class="icon-check"></i><i class="icon-ballSolid"></i></div><div class="match-results"><div class="results-wrapper"><div class="set set1"><span class="scores">6<span class="tiebreak"></span></span></div><div class="set set2"><span class="scores">4<span class="tiebreak"></span></span></div><div class="set set3"><span class="scores">4<span class="tiebreak"></span></span></div><div class="set set4"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set5"><span class="scores"><span class="tiebreak"></span></span></div></div></div></div></div><div class="match-box-buttons"><div class="generic-button_wrapper"><div class="generic-button compact watch-and-read" style="width: 100%;"><div class="content">Watch &amp; Read</div><div class="border"></div></div></div><div class="generic-button_wrapper"><a class="" href="/en_GB/scores/stats/2302.html"><div class="generic-button compact slamtracker-stats" style="width: 100%;"><div class="content">Stats by Slamtracker</div><div class="border"></div></div></a></div></div></div></div></div><div class="drawGroup   "><div><div class="match-box match-box-draws " data-dna="match-box-draws-page" data-match="2303"><div class="match-status"><div class="green-border"></div><div class="team-info team-one singles "><div class="team-name"><div class="member-one "><div class="flag"><img alt="USA" src="/assets/images/flags/USA_sm.gif"></div><div class="name"><a class="" href="/en_GB/players/overview/wta230234.html">S. Williams</a></div><div class="seed ">11</div></div><div class="member-two "><div class="flag"><img src="/assets/images/flags/null_sm.gif"></div><div class="name"></div><div class="seed ">11</div></div></div><div class="crticon winner"><i class="icon-check"></i><i class="icon-ballSolid"></i></div><div class="match-results"><div class="results-wrapper"><div class="set set1"><span class="scores">6<span class="tiebreak"></span></span></div><div class="set set2"><span class="scores">6<span class="tiebreak"></span></span></div><div class="set set3"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set4"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set5"><span class="scores"><span class="tiebreak"></span></span></div></div></div></div><div class="results-info"><div class="results-info-pts">PTS</div><div class="results-info-set">1</div><div class="results-info-set">2</div><div class="results-info-set">3</div><div class="results-info-set">4</div><div class="results-info-set">5</div></div><div class="team-info team-two singles "><div class="team-name"><div class="member-one "><div class="flag"><img alt="GER" src="/assets/images/flags/GER_sm.gif"></div><div class="name"><a class="" href="/en_GB/players/overview/wta313381.html">J. Goerges</a></div><div class="seed ">18</div></div><div class="member-two "><div class="flag"><img src="/assets/images/flags/null_sm.gif"></div><div class="name"></div><div class="seed ">18</div></div></div><div class="crticon"><i class="icon-check"></i><i class="icon-ballSolid"></i></div><div class="match-results"><div class="results-wrapper"><div class="set set1"><span class="scores">3<span class="tiebreak"></span></span></div><div class="set set2"><span class="scores">4<span class="tiebreak"></span></span></div><div class="set set3"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set4"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set5"><span class="scores"><span class="tiebreak"></span></span></div></div></div></div></div><div class="match-box-buttons"><div class="generic-button_wrapper"><div class="generic-button compact watch-and-read" style="width: 100%;"><div class="content">Watch &amp; Read</div><div class="border"></div></div></div><div class="generic-button_wrapper"><a class="" href="/en_GB/scores/stats/2303.html"><div class="generic-button compact slamtracker-stats" style="width: 100%;"><div class="content">Stats by Slamtracker</div><div class="border"></div></div></a></div></div></div></div></div><div class="drawGroup   "><div><div class="match-box match-box-draws " data-dna="match-box-draws-page" data-match="2304"><div class="match-status"><div class="green-border"></div><div class="team-info team-one singles "><div class="team-name"><div class="member-one "><div class="flag"><img alt="ESP" src="/assets/images/flags/ESP_sm.gif"></div><div class="name"><a class="" href="/en_GB/players/overview/wta311338.html">C. Suarez Navarro</a></div><div class="seed ">30</div></div><div class="member-two "><div class="flag"><img src="/assets/images/flags/null_sm.gif"></div><div class="name"></div><div class="seed ">30</div></div></div><div class="crticon winner"><i class="icon-check"></i><i class="icon-ballSolid"></i></div><div class="match-results"><div class="results-wrapper"><div class="set set1"><span class="scores">6<span class="tiebreak"></span></span></div><div class="set set2"><span class="scores">6<span class="tiebreak"></span></span></div><div class="set set3"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set4"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set5"><span class="scores"><span class="tiebreak"></span></span></div></div></div></div><div class="results-info"><div class="results-info-pts">PTS</div><div class="results-info-set">1</div><div class="results-info-set">2</div><div class="results-info-set">3</div><div class="results-info-set">4</div><div class="results-info-set">5</div></div><div class="team-info team-two singles "><div class="team-name"><div class="member-one "><div class="flag"><img alt="USA" src="/assets/images/flags/USA_sm.gif"></div><div class="name"><a class="" href="/en_GB/players/overview/wta317414.html">L. Davis</a></div><div class="seed hide"></div></div><div class="member-two "><div class="flag"><img src="/assets/images/flags/null_sm.gif"></div><div class="name"></div><div class="seed hide"></div></div></div><div class="crticon"><i class="icon-check"></i><i class="icon-ballSolid"></i></div><div class="match-results"><div class="results-wrapper"><div class="set set1"><span class="scores">3<span class="tiebreak"></span></span></div><div class="set set2"><span class="scores">3<span class="tiebreak"></span></span></div><div class="set set3"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set4"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set5"><span class="scores"><span class="tiebreak"></span></span></div></div></div></div></div><div class="match-box-buttons"><div class="generic-button_wrapper"><div class="generic-button compact watch-and-read" style="width: 100%;"><div class="content">Watch &amp; Read</div><div class="border"></div></div></div><div class="generic-button_wrapper"><a class="" href="/en_GB/scores/stats/2304.html"><div class="generic-button compact slamtracker-stats" style="width: 100%;"><div class="content">Stats by Slamtracker</div><div class="border"></div></div></a></div></div></div></div></div><div class="drawGroup   "><div><div class="match-box match-box-draws " data-dna="match-box-draws-page" data-match="2305"><div class="match-status"><div class="green-border"></div><div class="team-info team-one singles "><div class="team-name"><div class="member-one "><div class="flag"><img alt="NED" src="/assets/images/flags/NED_sm.gif"></div><div class="name"><a class="" href="/en_GB/players/overview/wta314584.html">K. Bertens</a></div><div class="seed ">4</div></div><div class="member-two "><div class="flag"><img src="/assets/images/flags/null_sm.gif"></div><div class="name"></div><div class="seed ">4</div></div></div><div class="crticon"><i class="icon-check"></i><i class="icon-ballSolid"></i></div><div class="match-results"><div class="results-wrapper"><div class="set set1"><span class="scores">5<span class="tiebreak"></span></span></div><div class="set set2"><span class="scores">1<span class="tiebreak"></span></span></div><div class="set set3"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set4"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set5"><span class="scores"><span class="tiebreak"></span></span></div></div></div></div><div class="results-info"><div class="results-info-pts">PTS</div><div class="results-info-set">1</div><div class="results-info-set">2</div><div class="results-info-set">3</div><div class="results-info-set">4</div><div class="results-info-set">5</div></div><div class="team-info team-two singles "><div class="team-name"><div class="member-one "><div class="flag"><img alt="CZE" src="/assets/images/flags/CZE_sm.gif"></div><div class="name"><a class="" href="/en_GB/players/overview/wta190879.html">B. Strycova</a></div><div class="seed hide"></div></div><div class="member-two "><div class="flag"><img src="/assets/images/flags/null_sm.gif"></div><div class="name"></div><div class="seed hide"></div></div></div><div class="crticon winner"><i class="icon-check"></i><i class="icon-ballSolid"></i></div><div class="match-results"><div class="results-wrapper"><div class="set set1"><span class="scores">7<span class="tiebreak"></span></span></div><div class="set set2"><span class="scores">6<span class="tiebreak"></span></span></div><div class="set set3"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set4"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set5"><span class="scores"><span class="tiebreak"></span></span></div></div></div></div></div><div class="match-box-buttons"><div class="generic-button_wrapper"><div class="generic-button compact watch-and-read" style="width: 100%;"><div class="content">Watch &amp; Read</div><div class="border"></div></div></div><div class="generic-button_wrapper"><a class="" href="/en_GB/scores/stats/2305.html"><div class="generic-button compact slamtracker-stats" style="width: 100%;"><div class="content">Stats by Slamtracker</div><div class="border"></div></div></a></div></div></div></div></div><div class="drawGroup   "><div><div class="match-box match-box-draws " data-dna="match-box-draws-page" data-match="2306"><div class="match-status"><div class="green-border"></div><div class="team-info team-one singles "><div class="team-name"><div class="member-one "><div class="flag"><img alt="BEL" src="/assets/images/flags/BEL_sm.gif"></div><div class="name"><a class="" href="/en_GB/players/overview/wta317964.html">E. Mertens</a></div><div class="seed ">21</div></div><div class="member-two "><div class="flag"><img src="/assets/images/flags/null_sm.gif"></div><div class="name"></div><div class="seed ">21</div></div></div><div class="crticon winner"><i class="icon-check"></i><i class="icon-ballSolid"></i></div><div class="match-results"><div class="results-wrapper"><div class="set set1"><span class="scores">6<span class="tiebreak"></span></span></div><div class="set set2"><span class="scores">6<span class="tiebreak">9</span></span></div><div class="set set3"><span class="scores">6<span class="tiebreak"></span></span></div><div class="set set4"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set5"><span class="scores"><span class="tiebreak"></span></span></div></div></div></div><div class="results-info"><div class="results-info-pts">PTS</div><div class="results-info-set">1</div><div class="results-info-set">2</div><div class="results-info-set">3</div><div class="results-info-set">4</div><div class="results-info-set">5</div></div><div class="team-info team-two singles "><div class="team-name"><div class="member-one "><div class="flag"><img alt="CHN" src="/assets/images/flags/CHN_sm.gif"></div><div class="name"><a class="" href="/en_GB/players/overview/wta314429.html">Q. Wang</a></div><div class="seed ">15</div></div><div class="member-two "><div class="flag"><img src="/assets/images/flags/null_sm.gif"></div><div class="name"></div><div class="seed ">15</div></div></div><div class="crticon"><i class="icon-check"></i><i class="icon-ballSolid"></i></div><div class="match-results"><div class="results-wrapper"><div class="set set1"><span class="scores">2<span class="tiebreak"></span></span></div><div class="set set2"><span class="scores">7<span class="tiebreak">11</span></span></div><div class="set set3"><span class="scores">4<span class="tiebreak"></span></span></div><div class="set set4"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set5"><span class="scores"><span class="tiebreak"></span></span></div></div></div></div></div><div class="match-box-buttons"><div class="generic-button_wrapper"><div class="generic-button compact watch-and-read" style="width: 100%;"><div class="content">Watch &amp; Read</div><div class="border"></div></div></div><div class="generic-button_wrapper"><a class="" href="/en_GB/scores/stats/2306.html"><div class="generic-button compact slamtracker-stats" style="width: 100%;"><div class="content">Stats by Slamtracker</div><div class="border"></div></div></a></div></div></div></div></div><div class="drawGroup   "><div><div class="match-box match-box-draws " data-dna="match-box-draws-page" data-match="2307"><div class="match-status"><div class="green-border"></div><div class="team-info team-one singles "><div class="team-name"><div class="member-one "><div class="flag"><img alt="USA" src="/assets/images/flags/USA_sm.gif"></div><div class="name"><a class="" href="/en_GB/players/overview/wta315683.html">S. Stephens</a></div><div class="seed ">9</div></div><div class="member-two "><div class="flag"><img src="/assets/images/flags/null_sm.gif"></div><div class="name"></div><div class="seed ">9</div></div></div><div class="crticon"><i class="icon-check"></i><i class="icon-ballSolid"></i></div><div class="match-results"><div class="results-wrapper"><div class="set set1"><span class="scores">6<span class="tiebreak"></span></span></div><div class="set set2"><span class="scores">4<span class="tiebreak"></span></span></div><div class="set set3"><span class="scores">1<span class="tiebreak"></span></span></div><div class="set set4"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set5"><span class="scores"><span class="tiebreak"></span></span></div></div></div></div><div class="results-info"><div class="results-info-pts">PTS</div><div class="results-info-set">1</div><div class="results-info-set">2</div><div class="results-info-set">3</div><div class="results-info-set">4</div><div class="results-info-set">5</div></div><div class="team-info team-two singles "><div class="team-name"><div class="member-one "><div class="flag"><img alt="GBR" src="/assets/images/flags/GBR_sm.gif"></div><div class="name"><a class="" href="/en_GB/players/overview/wta313907.html">J. Konta</a></div><div class="seed ">19</div></div><div class="member-two "><div class="flag"><img src="/assets/images/flags/null_sm.gif"></div><div class="name"></div><div class="seed ">19</div></div></div><div class="crticon winner"><i class="icon-check"></i><i class="icon-ballSolid"></i></div><div class="match-results"><div class="results-wrapper"><div class="set set1"><span class="scores">3<span class="tiebreak"></span></span></div><div class="set set2"><span class="scores">6<span class="tiebreak"></span></span></div><div class="set set3"><span class="scores">6<span class="tiebreak"></span></span></div><div class="set set4"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set5"><span class="scores"><span class="tiebreak"></span></span></div></div></div></div></div><div class="match-box-buttons"><div class="generic-button_wrapper"><div class="generic-button compact watch-and-read" style="width: 100%;"><div class="content">Watch &amp; Read</div><div class="border"></div></div></div><div class="generic-button_wrapper"><a class="" href="/en_GB/scores/stats/2307.html"><div class="generic-button compact slamtracker-stats" style="width: 100%;"><div class="content">Stats by Slamtracker</div><div class="border"></div></div></a></div></div></div></div></div><div class="drawGroup   "><div><div class="match-box match-box-draws " data-dna="match-box-draws-page" data-match="2308"><div class="match-status"><div class="green-border"></div><div class="team-info team-one singles "><div class="team-name"><div class="member-one "><div class="flag"><img alt="POL" src="/assets/images/flags/POL_sm.gif"></div><div class="name"><a class="" href="/en_GB/players/overview/wta315130.html">M. Linette</a></div><div class="seed hide"></div></div><div class="member-two "><div class="flag"><img src="/assets/images/flags/null_sm.gif"></div><div class="name"></div><div class="seed hide"></div></div></div><div class="crticon"><i class="icon-check"></i><i class="icon-ballSolid"></i></div><div class="match-results"><div class="results-wrapper"><div class="set set1"><span class="scores">3<span class="tiebreak"></span></span></div><div class="set set2"><span class="scores">2<span class="tiebreak"></span></span></div><div class="set set3"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set4"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set5"><span class="scores"><span class="tiebreak"></span></span></div></div></div></div><div class="results-info"><div class="results-info-pts">PTS</div><div class="results-info-set">1</div><div class="results-info-set">2</div><div class="results-info-set">3</div><div class="results-info-set">4</div><div class="results-info-set">5</div></div><div class="team-info team-two singles "><div class="team-name"><div class="member-one "><div class="flag"><img alt="CZE" src="/assets/images/flags/CZE_sm.gif"></div><div class="name"><a class="" href="/en_GB/players/overview/wta314206.html">P. Kvitova</a></div><div class="seed ">6</div></div><div class="member-two "><div class="flag"><img src="/assets/images/flags/null_sm.gif"></div><div class="name"></div><div class="seed ">6</div></div></div><div class="crticon winner"><i class="icon-check"></i><i class="icon-ballSolid"></i></div><div class="match-results"><div class="results-wrapper"><div class="set set1"><span class="scores">6<span class="tiebreak"></span></span></div><div class="set set2"><span class="scores">6<span class="tiebreak"></span></span></div><div class="set set3"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set4"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set5"><span class="scores"><span class="tiebreak"></span></span></div></div></div></div></div><div class="match-box-buttons"><div class="generic-button_wrapper"><div class="generic-button compact watch-and-read" style="width: 100%;"><div class="content">Watch &amp; Read</div><div class="border"></div></div></div><div class="generic-button_wrapper"><a class="" href="/en_GB/scores/stats/2308.html"><div class="generic-button compact slamtracker-stats" style="width: 100%;"><div class="content">Stats by Slamtracker</div><div class="border"></div></div></a></div></div></div></div></div></div><div class="roundGroup columnC draw-LS-round2"><h3>Fourth Round</h3><div class="drawGroup   "><div><div class="match-box match-box-draws " data-dna="match-box-draws-page" data-match="2401"><div class="match-status"><div class="green-border"></div><div class="team-info team-one singles "><div class="team-name"><div class="member-one "><div class="flag"><img alt="AUS" src="/assets/images/flags/AUS_sm.gif"></div><div class="name"><a class="" href="/en_GB/players/overview/wta318033.html">A. Barty</a></div><div class="seed ">1</div></div><div class="member-two "><div class="flag"><img src="/assets/images/flags/null_sm.gif"></div><div class="name"></div><div class="seed ">1</div></div></div><div class="crticon"><i class="icon-check"></i><i class="icon-ballSolid"></i></div><div class="match-results"><div class="results-wrapper"><div class="set set1"><span class="scores">6<span class="tiebreak"></span></span></div><div class="set set2"><span class="scores">2<span class="tiebreak"></span></span></div><div class="set set3"><span class="scores">3<span class="tiebreak"></span></span></div><div class="set set4"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set5"><span class="scores"><span class="tiebreak"></span></span></div></div></div></div><div class="results-info"><div class="results-info-pts">PTS</div><div class="results-info-set">1</div><div class="results-info-set">2</div><div class="results-info-set">3</div><div class="results-info-set">4</div><div class="results-info-set">5</div></div><div class="team-info team-two singles "><div class="team-name"><div class="member-one "><div class="flag"><img alt="USA" src="/assets/images/flags/USA_sm.gif"></div><div class="name"><a class="" href="/en_GB/players/overview/wta312850.html">A. Riske</a></div><div class="seed hide"></div></div><div class="member-two "><div class="flag"><img src="/assets/images/flags/null_sm.gif"></div><div class="name"></div><div class="seed hide"></div></div></div><div class="crticon winner"><i class="icon-check"></i><i class="icon-ballSolid"></i></div><div class="match-results"><div class="results-wrapper"><div class="set set1"><span class="scores">3<span class="tiebreak"></span></span></div><div class="set set2"><span class="scores">6<span class="tiebreak"></span></span></div><div class="set set3"><span class="scores">6<span class="tiebreak"></span></span></div><div class="set set4"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set5"><span class="scores"><span class="tiebreak"></span></span></div></div></div></div></div><div class="match-box-buttons"><div class="generic-button_wrapper"><div class="generic-button compact watch-and-read" style="width: 100%;"><div class="content">Watch &amp; Read</div><div class="border"></div></div></div><div class="generic-button_wrapper"><a class="" href="/en_GB/scores/stats/2401.html"><div class="generic-button compact slamtracker-stats" style="width: 100%;"><div class="content">Stats by Slamtracker</div><div class="border"></div></div></a></div></div></div></div></div><div class="drawGroup   "><div><div class="match-box match-box-draws " data-dna="match-box-draws-page" data-match="2402"><div class="match-status"><div class="green-border"></div><div class="team-info team-one singles "><div class="team-name"><div class="member-one "><div class="flag"><img alt="USA" src="/assets/images/flags/USA_sm.gif"></div><div class="name"><a class="" href="/en_GB/players/overview/wta230234.html">S. Williams</a></div><div class="seed ">11</div></div><div class="member-two "><div class="flag"><img src="/assets/images/flags/null_sm.gif"></div><div class="name"></div><div class="seed ">11</div></div></div><div class="crticon winner"><i class="icon-check"></i><i class="icon-ballSolid"></i></div><div class="match-results"><div class="results-wrapper"><div class="set set1"><span class="scores">6<span class="tiebreak"></span></span></div><div class="set set2"><span class="scores">6<span class="tiebreak"></span></span></div><div class="set set3"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set4"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set5"><span class="scores"><span class="tiebreak"></span></span></div></div></div></div><div class="results-info"><div class="results-info-pts">PTS</div><div class="results-info-set">1</div><div class="results-info-set">2</div><div class="results-info-set">3</div><div class="results-info-set">4</div><div class="results-info-set">5</div></div><div class="team-info team-two singles "><div class="team-name"><div class="member-one "><div class="flag"><img alt="ESP" src="/assets/images/flags/ESP_sm.gif"></div><div class="name"><a class="" href="/en_GB/players/overview/wta311338.html">C. Suarez Navarro</a></div><div class="seed ">30</div></div><div class="member-two "><div class="flag"><img src="/assets/images/flags/null_sm.gif"></div><div class="name"></div><div class="seed ">30</div></div></div><div class="crticon"><i class="icon-check"></i><i class="icon-ballSolid"></i></div><div class="match-results"><div class="results-wrapper"><div class="set set1"><span class="scores">2<span class="tiebreak"></span></span></div><div class="set set2"><span class="scores">2<span class="tiebreak"></span></span></div><div class="set set3"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set4"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set5"><span class="scores"><span class="tiebreak"></span></span></div></div></div></div></div><div class="match-box-buttons"><div class="generic-button_wrapper"><div class="generic-button compact watch-and-read" style="width: 100%;"><div class="content">Watch &amp; Read</div><div class="border"></div></div></div><div class="generic-button_wrapper"><a class="" href="/en_GB/scores/stats/2402.html"><div class="generic-button compact slamtracker-stats" style="width: 100%;"><div class="content">Stats by Slamtracker</div><div class="border"></div></div></a></div></div></div></div></div><div class="drawGroup   "><div><div class="match-box match-box-draws " data-dna="match-box-draws-page" data-match="2403"><div class="match-status"><div class="green-border"></div><div class="team-info team-one singles "><div class="team-name"><div class="member-one "><div class="flag"><img alt="CZE" src="/assets/images/flags/CZE_sm.gif"></div><div class="name"><a class="" href="/en_GB/players/overview/wta190879.html">B. Strycova</a></div><div class="seed hide"></div></div><div class="member-two "><div class="flag"><img src="/assets/images/flags/null_sm.gif"></div><div class="name"></div><div class="seed hide"></div></div></div><div class="crticon winner"><i class="icon-check"></i><i class="icon-ballSolid"></i></div><div class="match-results"><div class="results-wrapper"><div class="set set1"><span class="scores">4<span class="tiebreak"></span></span></div><div class="set set2"><span class="scores">7<span class="tiebreak"></span></span></div><div class="set set3"><span class="scores">6<span class="tiebreak"></span></span></div><div class="set set4"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set5"><span class="scores"><span class="tiebreak"></span></span></div></div></div></div><div class="results-info"><div class="results-info-pts">PTS</div><div class="results-info-set">1</div><div class="results-info-set">2</div><div class="results-info-set">3</div><div class="results-info-set">4</div><div class="results-info-set">5</div></div><div class="team-info team-two singles "><div class="team-name"><div class="member-one "><div class="flag"><img alt="BEL" src="/assets/images/flags/BEL_sm.gif"></div><div class="name"><a class="" href="/en_GB/players/overview/wta317964.html">E. Mertens</a></div><div class="seed ">21</div></div><div class="member-two "><div class="flag"><img src="/assets/images/flags/null_sm.gif"></div><div class="name"></div><div class="seed ">21</div></div></div><div class="crticon"><i class="icon-check"></i><i class="icon-ballSolid"></i></div><div class="match-results"><div class="results-wrapper"><div class="set set1"><span class="scores">6<span class="tiebreak"></span></span></div><div class="set set2"><span class="scores">5<span class="tiebreak"></span></span></div><div class="set set3"><span class="scores">2<span class="tiebreak"></span></span></div><div class="set set4"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set5"><span class="scores"><span class="tiebreak"></span></span></div></div></div></div></div><div class="match-box-buttons"><div class="generic-button_wrapper"><div class="generic-button compact watch-and-read" style="width: 100%;"><div class="content">Watch &amp; Read</div><div class="border"></div></div></div><div class="generic-button_wrapper"><a class="" href="/en_GB/scores/stats/2403.html"><div class="generic-button compact slamtracker-stats" style="width: 100%;"><div class="content">Stats by Slamtracker</div><div class="border"></div></div></a></div></div></div></div></div><div class="drawGroup   "><div><div class="match-box match-box-draws " data-dna="match-box-draws-page" data-match="2404"><div class="match-status"><div class="green-border"></div><div class="team-info team-one singles "><div class="team-name"><div class="member-one "><div class="flag"><img alt="GBR" src="/assets/images/flags/GBR_sm.gif"></div><div class="name"><a class="" href="/en_GB/players/overview/wta313907.html">J. Konta</a></div><div class="seed ">19</div></div><div class="member-two "><div class="flag"><img src="/assets/images/flags/null_sm.gif"></div><div class="name"></div><div class="seed ">19</div></div></div><div class="crticon winner"><i class="icon-check"></i><i class="icon-ballSolid"></i></div><div class="match-results"><div class="results-wrapper"><div class="set set1"><span class="scores">4<span class="tiebreak"></span></span></div><div class="set set2"><span class="scores">6<span class="tiebreak"></span></span></div><div class="set set3"><span class="scores">6<span class="tiebreak"></span></span></div><div class="set set4"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set5"><span class="scores"><span class="tiebreak"></span></span></div></div></div></div><div class="results-info"><div class="results-info-pts">PTS</div><div class="results-info-set">1</div><div class="results-info-set">2</div><div class="results-info-set">3</div><div class="results-info-set">4</div><div class="results-info-set">5</div></div><div class="team-info team-two singles "><div class="team-name"><div class="member-one "><div class="flag"><img alt="CZE" src="/assets/images/flags/CZE_sm.gif"></div><div class="name"><a class="" href="/en_GB/players/overview/wta314206.html">P. Kvitova</a></div><div class="seed ">6</div></div><div class="member-two "><div class="flag"><img src="/assets/images/flags/null_sm.gif"></div><div class="name"></div><div class="seed ">6</div></div></div><div class="crticon"><i class="icon-check"></i><i class="icon-ballSolid"></i></div><div class="match-results"><div class="results-wrapper"><div class="set set1"><span class="scores">6<span class="tiebreak"></span></span></div><div class="set set2"><span class="scores">2<span class="tiebreak"></span></span></div><div class="set set3"><span class="scores">4<span class="tiebreak"></span></span></div><div class="set set4"><span class="scores"><span class="tiebreak"></span></span></div><div class="set set5"><span class="scores"><span class="tiebreak"></span></span></div></div></div></div></div><div class="match-box-buttons"><div class="generic-button_wrapper"><div class="generic-button compact watch-and-read" style="width: 100%;"><div class="content">Watch &amp; Read</div><div class="border"></div></div></div><div class="generic-button_wrapper"><a class="" href="/en_GB/scores/stats/2404.html"><div class="generic-button compact slamtracker-stats" style="width: 100%;"><div class="content">Stats by Slamtracker</div><div class="border"></div></div></a></div></div></div></div></div></div></div></div></div></div><footer><div class="footer-global"><div class="greenstripe-container"><div class="greenStripe"></div></div><div class="footer-flex"><div class="footer-global-social"><div class="footer-global-social-wrapper"><div class="share-bar black"><div class="share-bar-icons"><i class="icon-facebook external" title="Facebook"></i><i class="icon-twitter external" title="Twitter"></i><i class="icon-instagram external" title="Instagram"></i><i class="icon-youtube external" title="YouTube"></i><i class="icon-wechat external" title="WeChat"></i><i class="icon-weibo external" title="Weibo"></i></div></div></div></div><div class="footer-global-links"><a href="/en_GB/contact/index.html">Contact</a><a href="/en_GB/jobs/index.html">Jobs</a><a href="/en_GB/media/index.html">Media</a><a href="/en_GB/about_wimbledon/privacy.html">Privacy</a></div><div class="footer-global-copyright">© Copyright IBM Corp., AELTC 2019. All Rights reserved.</div></div></div></footer></section></div> """

# %%
wimb_soup = BeautifulSoup(wimb_html, 'lxml')
print(wimb_soup.prettify())

# %% [markdown]
# # **Batsy's game**

# %%
secondround=wimb_soup.find(attrs={"class": "roundGroup columnA draw-LS-round2"})
secondround.h3.string
# Out:
# u'Second Round'

# %%
batsy=wimb_soup.find(attrs={"class": "team-info team-one singles "})
print(batsy.prettify())
# Out:
# <div class="team-info team-one singles ">
#  <div class="team-name">
#   <div class="member-one ">
#    <div class="flag">
#     <img alt="AUS" src="/assets/images/flags/AUS_sm.gif"/>
#    </div>
#    <div class="name">
#     <a class="" href="/en_GB/players/overview/wta318033.html">
#      A. Barty
#     </a>
#    </div>
#    <div class="seed ">
#     1
#    </div>
#   </div>
#   <div class="member-two ">
#    <div class="flag">
#     <img src="/assets/images/flags/null_sm.gif"/>
#    </div>
#    <div class="name">
#    </div>
#    <div class="seed ">
#     1
#    </div>
#   </div>
#  </div>
#  <div class="crticon winner">
#   <i class="icon-check">
#   </i>
#   <i class="icon-ballSolid">
#   </i>
#  </div>
#  <div class="match-results">
#   <div class="results-wrapper">
#    <div class="set set1">
#     <span class="scores">
#      6
#      <span class="tiebreak">
#      </span>
#     </span>
#    </div>
#    <div class="set set2">
#     <span class="scores">
#      6
# ...

# %%
import re
name=batsy.find_all("a", string="A. Barty")[0].text
print(name)
# Out:
# A. Barty

# %%
set1=batsy.find(attrs={"class": "set set1"})
set1.text
# Out:
# u'6'

# %%
set2=batsy.find(attrs={"class": "set set2"})
set2.text
# Out:
# u'6'
